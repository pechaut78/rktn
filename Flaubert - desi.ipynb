# %% [markdown]
# Camembert pour les designations
#
# - On entraine
# - On sauve le modele
# - On Evalue le modele
# - On recharge le modele, génère les embeddings et les sauve dans un CSV

# %%
from RktnChallenge.RktnModel import ModelTrainer



import tensorflow as tf

import pandas as pd
import numpy as np
import ast
import tensorflow as tf
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, TFFlaubertForSequenceClassification
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import AdamW


# Reste du code (reprend à partir de la définition de convert_and_join)

trainer = ModelTrainer("data_tr.csv", "")
nb_epochs = 20
num_categories = 27
max_features = 400
checkpoint_path = "flaubert_best_desi_tr"

def convert_and_join(str_list):
    try:
        # Convertir la chaîne en liste
        real_list = ast.literal_eval(str_list)
        # Joindre la liste pour former une chaîne
        return " ".join(real_list)
    except (ValueError, SyntaxError):
        return ""


# Charger le modèle Flaubert et le tokenizer
modelpoint = 'jplu/tf-flaubert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(modelpoint)
model = TFFlaubertForSequenceClassification.from_pretrained(modelpoint, num_labels=num_categories)

labels = y = trainer.encodeLabel("prdtypecode")
#sentences =  trainer.data["designation_tkn_lemm"].apply(convert_and_join).values.tolist()
sentences =  trainer.data["tr_designation"].values.tolist()

sentences_train, sentences_test, labels_train, labels_test = train_test_split(sentences, labels, test_size=0.2, random_state=42)
sentences_train, sentences_val, labels_train, labels_val = train_test_split(sentences_train, labels_train, test_size=0.1, random_state=42)






def encode_sentences(sentences, tokenizer, max_length=max_features):
    encodings = tokenizer(sentences, padding='max_length', truncation=True, max_length=max_length, return_tensors='tf')
    return {"input_ids": encodings["input_ids"], "attention_mask": encodings["attention_mask"]}
    

print("encoding sentences...")
X_train = encode_sentences(sentences_train, tokenizer)
X_val = encode_sentences(sentences_val, tokenizer)
X_test = encode_sentences(sentences_test, tokenizer)



y_train = np.array(labels_train)
y_val = np.array(labels_val)
y_test = np.array(labels_test)

from transformers import AdamWeightDecay

print("compile model...")
#optimizer = AdamW(weight_decay=0.01, learning_rate=2e-5, epsilon=1e-08, clipnorm=1.0) 
optimizer = Adam(learning_rate=2e-5, epsilon=1e-08, clipnorm=1.0)
loss = SparseCategoricalCrossentropy(from_logits=True)

for layer in model.layers:
    layer.trainable = False
num_layers = len(model.layers)
for i in range(num_layers - 2, num_layers): 
    model.layers[i].trainable = True
    
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

early_stopper = tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy', mode='auto', patience=3, 
            verbose=1, restore_best_weights=True
        ) 

print("fit...")
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=nb_epochs, batch_size=8, callbacks=[early_stopper])
model.save_pretrained(checkpoint_path)
tokenizer.save_pretrained(checkpoint_path)
# Out:
# 2023-09-25 11:47:20.200790: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-25 11:47:20.228341: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9511] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-25 11:47:20.228371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-25 11:47:20.228387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-25 11:47:20.235477: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-25 11:47:20.794145: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-25 11:47:24.549162: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:24.549952: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:24.550172: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:24.551435: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:24.551627: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:24.551837: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:26.165682: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:26.166105: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:26.166116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2003] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-09-25 11:47:26.166343: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:47:26.166363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1912] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1277 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:02:00.0, compute capability: 6.1
# Some layers from the model checkpoint at jplu/tf-flaubert-base-cased were not used when initializing TFFlaubertForSequenceClassification: ['pred_layer_._proj']
# - This IS expected if you are initializing TFFlaubertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFFlaubertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFFlaubertForSequenceClassification were not initialized from the model checkpoint at jplu/tf-flaubert-base-cased and are newly initialized: ['sequence_summary']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# encoding sentences...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/pec/Rktn/Flaubert - desi.ipynb Cellule 2 line 6
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a> X_train = encode_sentences(sentences_train, tokenizer)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=60'>61</a> X_val = encode_sentences(sentences_val, tokenizer)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a> X_test = encode_sentences(sentences_test, tokenizer)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> y_train = np.array(labels_train)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> y_val = np.array(labels_val)
#
# /home/pec/Rktn/Flaubert - desi.ipynb Cellule 2 line 5
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a> def encode_sentences(sentences, tokenizer, max_length=max_features):
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a>     encodings = tokenizer(sentences, padding='max_length', truncation=True, max_length=max_length, return_tensors='tf')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pec/Rktn/Flaubert%20-%20desi.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a>     return {"input_ids": encodings["input_ids"], "attention_mask": encodings["attention_mask"]}
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2561, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2559     if not self._in_target_context_manager:
#    2560         self._switch_to_input_mode()
# -> 2561     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2562 if text_target is not None:
#    2563     self._switch_to_target_mode()
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2647, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2642         raise ValueError(
#    2643             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2644             f" {len(text_pair)}."
#    2645         )
#    2646     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2647     return self.batch_encode_plus(
#    2648         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2649         add_special_tokens=add_special_tokens,
#    2650         padding=padding,
#    2651         truncation=truncation,
#    2652         max_length=max_length,
#    2653         stride=stride,
#    2654         is_split_into_words=is_split_into_words,
#    2655         pad_to_multiple_of=pad_to_multiple_of,
#    2656         return_tensors=return_tensors,
#    2657         return_token_type_ids=return_token_type_ids,
#    2658         return_attention_mask=return_attention_mask,
#    2659         return_overflowing_tokens=return_overflowing_tokens,
#    2660         return_special_tokens_mask=return_special_tokens_mask,
#    2661         return_offsets_mapping=return_offsets_mapping,
#    2662         return_length=return_length,
#    2663         verbose=verbose,
#    2664         **kwargs,
#    2665     )
#    2666 else:
#    2667     return self.encode_plus(
#    2668         text=text,
#    2669         text_pair=text_pair,
#    (...)
#    2685         **kwargs,
#    2686     )
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2838, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2828 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2829 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2830     padding=padding,
#    2831     truncation=truncation,
#    (...)
#    2835     **kwargs,
#    2836 )
# -> 2838 return self._batch_encode_plus(
#    2839     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2840     add_special_tokens=add_special_tokens,
#    2841     padding_strategy=padding_strategy,
#    2842     truncation_strategy=truncation_strategy,
#    2843     max_length=max_length,
#    2844     stride=stride,
#    2845     is_split_into_words=is_split_into_words,
#    2846     pad_to_multiple_of=pad_to_multiple_of,
#    2847     return_tensors=return_tensors,
#    2848     return_token_type_ids=return_token_type_ids,
#    2849     return_attention_mask=return_attention_mask,
#    2850     return_overflowing_tokens=return_overflowing_tokens,
#    2851     return_special_tokens_mask=return_special_tokens_mask,
#    2852     return_offsets_mapping=return_offsets_mapping,
#    2853     return_length=return_length,
#    2854     verbose=verbose,
#    2855     **kwargs,
#    2856 )
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils.py:733, in PreTrainedTokenizer._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     730 else:
#     731     ids, pair_ids = ids_or_pair_ids
# --> 733 first_ids = get_input_ids(ids)
#     734 second_ids = get_input_ids(pair_ids) if pair_ids is not None else None
#     735 input_ids.append((first_ids, second_ids))
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils.py:700, in PreTrainedTokenizer._batch_encode_plus.<locals>.get_input_ids(text)
#     698 def get_input_ids(text):
#     699     if isinstance(text, str):
# --> 700         tokens = self.tokenize(text, **kwargs)
#     701         return self.convert_tokens_to_ids(tokens)
#     702     elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/tokenization_utils.py:547, in PreTrainedTokenizer.tokenize(self, text, **kwargs)
#     545         tokenized_text.append(token)
#     546     else:
# --> 547         tokenized_text.extend(self._tokenize(token))
#     548 # ["This", " is", " something", "<special_token_1>", "else"]
#     549 return tokenized_text
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/models/flaubert/tokenization_flaubert.py:449, in FlaubertTokenizer._tokenize(self, text, bypass_tokenizer)
#     447 else:
#     448     text = self.preprocess_text(text)
# --> 449     text = self.moses_pipeline(text, lang=lang)
#     450     text = self.moses_tokenize(text, lang=lang)
#     452 split_tokens = []
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/models/flaubert/tokenization_flaubert.py:332, in FlaubertTokenizer.moses_pipeline(self, text, lang)
#     330 def moses_pipeline(self, text, lang):
#     331     text = replace_unicode_punct(text)
# --> 332     text = self.moses_punct_norm(text, lang)
#     333     text = remove_non_printing_char(text)
#     334     return text
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/transformers/models/flaubert/tokenization_flaubert.py:318, in FlaubertTokenizer.moses_punct_norm(self, text, lang)
#     316 else:
#     317     punct_normalizer = self.cache_moses_punct_normalizer[lang]
# --> 318 return punct_normalizer.normalize(text)
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/site-packages/sacremoses/normalize.py:185, in MosesPunctNormalizer.normalize(self, text)
#     182 # Actual normalization.
#     183 for regexp, substitution in self.substitutions:
#     184     # print(regexp, substitution)
# --> 185     text = re.sub(regexp, substitution, text_type(text))
#     186     # print(text)
#     187
#     188 # Optionally, replace unicode puncts BEFORE normalization.
#     189 if self.post_remove_control_chars:
#
# File ~/miniconda3/envs/tfGPU/lib/python3.9/re.py:210, in sub(pattern, repl, string, count, flags)
#     203 def sub(pattern, repl, string, count=0, flags=0):
#     204     """Return the string obtained by replacing the leftmost
#     205     non-overlapping occurrences of the pattern in string by the
#     206     replacement repl.  repl can be either a string or a callable;
#     207     if a string, backslash escapes in it are processed.  If it is
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#
# KeyboardInterrupt:

# %%
model.save_pretrained(checkpoint_path)
tokenizer.save_pretrained(checkpoint_path)
# Out:
# Les cellules en cours d’exécution avec /bin/python3 nécessitent le package ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from RktnChallenge.RktnModel import ModelTrainer



import tensorflow as tf


import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import CamembertTokenizer, TFCamembertForSequenceClassification
# Load the model

tokenizer = AutoTokenizer.from_pretrained(checkpoint_path)
model = TFFlaubertForSequenceClassification.from_pretrained(checkpoint_path)
# Out:
# All model checkpoint layers were used when initializing TFFlaubertForSequenceClassification.
#
# All the layers of TFFlaubertForSequenceClassification were initialized from the model checkpoint at flaubert_best_desi_tr.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFFlaubertForSequenceClassification for predictions without further training.

# %%
y_pred_test = model.predict(X_test)
# Out:
# 2023-09-25 03:20:36.650258: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# autotune_options {
# }
# warm_start: false
# 531/531 [==============================] - 328s 615ms/step

# %%
#designation traduction
y_pred_out = y_pred_test.logits
y_pred = np.argmax(y_pred_out, axis=-1)

trainer.evaluateTestResults(y_test,y_pred)
# Out:
# weighted F1 score: 0.8575234312442923

# %%
#designation directement sans traduction
y_pred_out = y_pred_test.logits
y_pred = np.argmax(y_pred_out, axis=-1)

trainer.evaluateTestResults(y_test,y_pred)
# Out:
# weighted F1 score: 0.8470213418837268

# %%
from RktnChallenge.RktnModel import ModelTrainer
import tensorflow as tf


import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import  CamembertConfig
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import AdamW

import ast

trainer = ModelTrainer("data_tr.csv","")
nb_epochs = 10
num_categories = 27
max_features = 400
checkpoint_path = "flaubert_best_desi_tr_8575"

def convert_and_join(str_list):
    try:
        # Convertir la chaîne en liste
        real_list = ast.literal_eval(str_list)
        # Joindre la liste pour former une chaîne
        return " ".join(real_list)
    except (ValueError, SyntaxError):
        return ""



#sentences =  trainer.data["tr_designation"].apply(convert_and_join).values.tolist()
sentences =  trainer.data["tr_designation"].values.tolist()
from transformers import FlaubertConfig, TFFlaubertModel, AutoTokenizer

config = FlaubertConfig.from_pretrained(checkpoint_path)
config.num_labels = 27
tokenizer = AutoTokenizer.from_pretrained(checkpoint_path)
model = TFFlaubertModel.from_pretrained(checkpoint_path, config=config)


for layer in model.layers:
    layer.trainable = False
# Out:
# 2023-09-25 11:52:15.330554: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-25 11:52:15.355010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9511] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-25 11:52:15.355034: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-25 11:52:15.355048: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-25 11:52:15.360768: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-25 11:52:15.948462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-25 11:52:18.818806: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:18.820373: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:18.820930: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:18.823735: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:18.824277: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:18.824604: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:20.409049: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:20.409679: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:20.409721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2003] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-09-25 11:52:20.410336: I external/local_xla/xla/stream_executor/cuda/cuda_gpu_executor.cc:885] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-25 11:52:20.410374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1912] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1256 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:02:00.0, compute capability: 6.1
# Some layers from the model checkpoint at flaubert_best_desi_tr_8575 were not used when initializing TFFlaubertModel: ['sequence_summary']
# - This IS expected if you are initializing TFFlaubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFFlaubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFFlaubertModel were initialized from the model checkpoint at flaubert_best_desi_tr_8575.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFFlaubertModel for predictions without further training.

# %%
from tqdm import tqdm

def sentence_to_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="tf", truncation=True,  max_length=max_features)
    outputs = model(inputs.input_ids)
    embeddings = outputs.last_hidden_state
    
    embeddings = tf.reduce_mean(embeddings, axis=1)    
    return embeddings.numpy()

df = pd.read_csv("embeddings_final.csv")

# embeddings pour chaque texte
df['embeddings_desi_Flaubert'] = [sentence_to_embedding(text) for text in tqdm(sentences)]

df.to_csv("embeddings_final.csv", index=False)
# Out:
# 100%|██████████| 84916/84916 [2:57:59<00:00,  7.95it/s]

# %%
print(df['embeddings_desi_Flaubert'][0].shape)
# Out:
# (1, 768)
